# %%
import pandas as pd
import random
import numpy as np


ff2020 = pd.read_csv("fantasy/fantasy_data_2020.csv")
ff2021 = pd.read_csv("fantasy/fantasy_data_2021.csv")

# %%
raw_scores = ff2021[['team_name', 'week', 'points']].drop_duplicates()
raw_scores.week.max()
# Out:
# 2

# %%
def split(df, col):
    return [x for _, x in df.groupby(col)]

def create_team_dict(raw_scores):
    '''Create dictionary of team names and their scores'''
    team_scores = split(raw_scores, 'team_name')
    team_dict = {}
    for i in team_scores:
        team_name = i.team_name.drop_duplicates().values[0]
        team_dict.update({team_name:i.points.values})
    return team_dict

def simulate_season(team_name, team_dict):
    opponents = [i for i in list(team_dict.keys()) if i != team_name]
    # Randomize order of opponents

    # Get maximum number of games so far
    games_count = len(team_dict[team_name])

    all_wins = []
    for i in range(10000):
        new_order = random.sample(opponents, games_count) 
        wins = 0
        for j, opp in enumerate(new_order):
            my_points = team_dict[team_name][j]
            opp_points = team_dict[opp][j]
            if my_points > opp_points:
                wins += 1
        all_wins.append(wins)
    return all_wins

def build_probability_distribution(raw_scores):
    team_dict = create_team_dict(raw_scores)
    all_team_names = sorted(list(set(raw_scores.team_name.values)))
    simulated_wins = []
    for name in all_team_names:
        total_wins = pd.Series(simulate_season(name, team_dict))
        total_wins = total_wins.rename(name)
        simulated_wins.append(total_wins.value_counts() / total_wins.value_counts().sum())

    return pd.concat(simulated_wins, axis=1).fillna(0)

# %%
liklihood_table = build_probability_distribution(raw_scores).sort_index(ascending=False).cumsum(axis=0).sort_index(ascending=True)
format_dict = {col:'{:,.1%}'.format for col in liklihood_table.columns }

# %%
liklihood_table.style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_7b715788_1d4b_11ec_9520_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >12th in Name Power Rankings</th>        <th class="col_heading level0 col1" >49ers QB of the Future</th>        <th class="col_heading level0 col2" >ACL Count: 1</th>        <th class="col_heading level0 col3" >Born Again Christian</th>        <th class="col_heading level0 col4" >Derrickle McNichols</th>        <th class="col_heading level0 col5" >Edward  Jordyhands </th>        <th class="col_heading level0 col6" >Finding Deebo</th>        <th class="col_heading level0 col7" >Jerry Jones'  Blood Boy</th>        <th class="col_heading level0 col8" >Joe Rogan on Horse Dewormer</th>        <th class="col_heading level0 col9" >Murray Up Offense</th>        <th class="col_heading level0 col10" >Qaptain Qirk And the Qrew</th>        <th class="col_heading level0 col11" >The Salty Spitoon</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7b715788_1d4b_11ec_9520_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_7b715788_1d4b_11ec_9520_acde48001122row0_col0" class="data row0 col0" >100.0%</td>
#                         <td id="T_7b715788_1d4b_11ec_9520_acde48001122row0_col1" class="data row0 col1" >100.0%</td>
#                         <td id="T_7b715788_1d4b_11ec_9520_acde48001122row0_col2" class="data row0 col2" >100.0%</td>
#                         <td id="T_7b715788_1d4b_11ec_9520_acde48001122row0_col3" class="data row0 col3" >100.0%</td>
#                         <td id="T_7b715788_1d4b_11ec_9520_acde48001122row0_col4" class="data row0 col4" >100.0%</td>
#                         <td id="T_7b715788_1d4b_11ec_9520_acde48001122row0_col5" class="data row0 col5" >100.0%</td>
#                         <td id="T_7b715788_1d4b_11ec_9520_acde48001122row0_col6" class="data row0 col6" >100.0%</td>
#                         <td id="T_7b715788_1d4b_11ec_9520_acde48001122row0_col7" class="data row0 col7" >100.0%</td>
#                         <td id="T_7b715788_1d4b_11ec_9520_acde48001122row0_col8" class="data row0 col8" >100.0%</td>
#                         <td id="T_7b715788_1d4b_11ec_9520_acde48001122row0_col9" class="data row0 col9" >100.0%</td>
#                         <td id="T_7b715788_1d4b_11ec_9520_acde48001122row0_col10" class="data row0 col10" >100.0%</td>
#                         <td id="T_7b715788_1d4b_11ec_9520_acde48001122row0_col11" class="data row0 col11" >100.0%</td>
#             </tr>
#             <tr>
#                         <th id="T_7b715788_1d4b_11ec_9520_acde48001122level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_7b715788_1d4b_11ec_9520_acde48001122row1_col0" class="data row1 col0" >55.0%</td>
#                         <td id="T_7b715788_1d4b_11ec_9520_acde48001122row1_col1" class="data row1 col1" >27.2%</td>
#                         <td id="T_7b715788_1d4b_11ec_9520_acde48001122row1_col2" class="data row1 col2" >32.5%</td>
#                         <td id="T_7b715788_1d4b_11ec_9520_acde48001122row1_col3" class="data row1 col3" >79.7%</td>
#                         <td id="T_7b715788_1d4b_11ec_9520_acde48001122row1_col4" class="data row1 col4" >93.0%</td>
#                         <td id="T_7b715788_1d4b_11ec_9520_acde48001122row1_col5" class="data row1 col5" >94.4%</td>
#                         <td id="T_7b715788_1d4b_11ec_9520_acde48001122row1_col6" class="data row1 col6" >100.0%</td>
#                         <td id="T_7b715788_1d4b_11ec_9520_acde48001122row1_col7" class="data row1 col7" >91.3%</td>
#                         <td id="T_7b715788_1d4b_11ec_9520_acde48001122row1_col8" class="data row1 col8" >74.2%</td>
#                         <td id="T_7b715788_1d4b_11ec_9520_acde48001122row1_col9" class="data row1 col9" >100.0%</td>
#                         <td id="T_7b715788_1d4b_11ec_9520_acde48001122row1_col10" class="data row1 col10" >74.3%</td>
#                         <td id="T_7b715788_1d4b_11ec_9520_acde48001122row1_col11" class="data row1 col11" >92.0%</td>
#             </tr>
#             <tr>
#                         <th id="T_7b715788_1d4b_11ec_9520_acde48001122level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_7b715788_1d4b_11ec_9520_acde48001122row2_col0" class="data row2 col0" >8.7%</td>
#                         <td id="T_7b715788_1d4b_11ec_9520_acde48001122row2_col1" class="data row2 col1" >0.0%</td>
#                         <td id="T_7b715788_1d4b_11ec_9520_acde48001122row2_col2" class="data row2 col2" >3.7%</td>
#                         <td id="T_7b715788_1d4b_11ec_9520_acde48001122row2_col3" class="data row2 col3" >29.0%</td>
#                         <td id="T_7b715788_1d4b_11ec_9520_acde48001122row2_col4" class="data row2 col4" >51.8%</td>
#                         <td id="T_7b715788_1d4b_11ec_9520_acde48001122row2_col5" class="data row2 col5" >59.9%</td>
#                         <td id="T_7b715788_1d4b_11ec_9520_acde48001122row2_col6" class="data row2 col6" >36.7%</td>
#                         <td id="T_7b715788_1d4b_11ec_9520_acde48001122row2_col7" class="data row2 col7" >0.0%</td>
#                         <td id="T_7b715788_1d4b_11ec_9520_acde48001122row2_col8" class="data row2 col8" >6.9%</td>
#                         <td id="T_7b715788_1d4b_11ec_9520_acde48001122row2_col9" class="data row2 col9" >54.4%</td>
#                         <td id="T_7b715788_1d4b_11ec_9520_acde48001122row2_col10" class="data row2 col10" >24.6%</td>
#                         <td id="T_7b715788_1d4b_11ec_9520_acde48001122row2_col11" class="data row2 col11" >7.7%</td>
#             </tr>
#     </tbody></table>

# %%
win_probs = []
for x,i  in enumerate(dfs):
    i['win_probability'] = i['points'].rank() / i['points'].count()
    i['week'] = x
    win_probs.append(i[['team_name', 'win_probability', 'week']])

# %%
all_probs = pd.concat(win_probs)

# %%
team_split = split(all_probs, 'team_name')

# %%
def simulate_season(my_team_probs):
    total_wins = []
    for i in my_team_probs:
        total_wins.append(np.random.binomial(1,i))
    return total_wins

# %%
team_names = sorted(list(all_probs.team_name.drop_duplicates()))
team_split
# Out:
# [      team_name  win_probability  week
#  6    49ers 14-6         0.166667     0
#  45   49ers 14-6         0.250000     1
#  78   49ers 14-6         0.333333     2
#  117  49ers 14-6         0.833333     3
#  150  49ers 14-6         0.500000     4
#  189  49ers 14-6         0.083333     5
#  222  49ers 14-6         0.250000     6
#  261  49ers 14-6         0.083333     7
#  294  49ers 14-6         0.083333     8
#  327  49ers 14-6         0.500000     9
#  366  49ers 14-6         0.500000    10
#  405  49ers 14-6         0.416667    11
#  441  49ers 14-6         0.083333    12,
#              team_name  win_probability  week
#  3    American Russell         0.250000     0
#  36   American Russell         0.583333     1
#  75   American Russell         0.916667     2
#  108  American Russell         0.083333     3
#  144  American Russell         0.416667     4
#  183  American Russell         0.666667     5
#  216  American Russell         0.750000     6
#  255  American Russell         0.833333     7
#  288  American Russell         0.833333     8
#  324  American Russell         0.083333     9
#  363  American Russell         0.083333    10
#  396  American Russell         0.666667    11
#  432  American Russell         0.416667    12,
#            team_name  win_probability  week
#  15   Clapped Cheeks         0.083333     0
#  54   Clapped Cheeks         0.166667     1
#  99   Clapped Cheeks         0.083333     2
#  138  Clapped Cheeks         0.500000     3
#  147  Clapped Cheeks         0.750000     4
#  213  Clapped Cheeks         0.500000     5
#  240  Clapped Cheeks         0.833333     6
#  273  Clapped Cheeks         0.583333     7
#  300  Clapped Cheeks         0.333333     8
#  333  Clapped Cheeks         0.250000     9
#  369  Clapped Cheeks         0.166667    10
#  408  Clapped Cheeks         0.083333    11
#  447  Clapped Cheeks         0.833333    12,
#            team_name  win_probability  week
#  9    Double D Kupps         1.000000     0
#  48   Double D Kupps         0.916667     1
#  93   Double D Kupps         1.000000     2
#  132  Double D Kupps         0.250000     3
#  177  Double D Kupps         0.250000     4
#  210  Double D Kupps         0.416667     5
#  246  Double D Kupps         1.000000     6
#  279  Double D Kupps         1.000000     7
#  306  Double D Kupps         0.250000     8
#  339  Double D Kupps         0.750000     9
#  360  Double D Kupps         0.333333    10
#  402  Double D Kupps         0.500000    11
#  453  Double D Kupps         0.500000    12,
#                team_name  win_probability  week
#  0    Edward  Jordyhands         0.750000     0
#  51   Edward  Jordyhands         1.000000     1
#  81   Edward  Jordyhands         0.750000     2
#  120  Edward  Jordyhands         0.416667     3
#  165  Edward  Jordyhands         0.833333     4
#  204  Edward  Jordyhands         0.916667     5
#  243  Edward  Jordyhands         0.500000     6
#  282  Edward  Jordyhands         0.916667     7
#  318  Edward  Jordyhands         0.916667     8
#  351  Edward  Jordyhands         0.833333     9
#  378  Edward  Jordyhands         0.750000    10
#  399  Edward  Jordyhands         0.916667    11
#  459  Edward  Jordyhands         0.666667    12,
#           team_name  win_probability  week
#  30   Finding Deebo         0.916667     0
#  63   Finding Deebo         0.416667     1
#  96   Finding Deebo         0.583333     2
#  129  Finding Deebo         0.583333     3
#  156  Finding Deebo         0.916667     4
#  186  Finding Deebo         0.333333     5
#  231  Finding Deebo         0.083333     6
#  252  Finding Deebo         0.250000     7
#  309  Finding Deebo         0.666667     8
#  348  Finding Deebo         0.416667     9
#  393  Finding Deebo         0.583333    10
#  429  Finding Deebo         0.166667    11
#  462  Finding Deebo         1.000000    12,
#                 team_name  win_probability  week
#  27   It Ertz  When I Pee         0.333333     0
#  66   It Ertz  When I Pee         0.083333     1
#  102  It Ertz  When I Pee         0.666667     2
#  141  It Ertz  When I Pee         0.333333     3
#  168  It Ertz  When I Pee         0.166667     4
#  201  It Ertz  When I Pee         1.000000     5
#  228  It Ertz  When I Pee         0.416667     6
#  258  It Ertz  When I Pee         0.416667     7
#  291  It Ertz  When I Pee         0.500000     8
#  336  It Ertz  When I Pee         0.583333     9
#  381  It Ertz  When I Pee         1.000000    10
#  420  It Ertz  When I Pee         1.000000    11
#  435  It Ertz  When I Pee         0.166667    12,
#                 team_name  win_probability  week
#  21   Smoke Herb Everyday         0.416667     0
#  60   Smoke Herb Everyday         0.500000     1
#  105  Smoke Herb Everyday         0.250000     2
#  111  Smoke Herb Everyday         1.000000     3
#  174  Smoke Herb Everyday         0.083333     4
#  207  Smoke Herb Everyday         0.833333     5
#  234  Smoke Herb Everyday         0.916667     6
#  267  Smoke Herb Everyday         0.750000     7
#  297  Smoke Herb Everyday         0.416667     8
#  330  Smoke Herb Everyday         1.000000     9
#  375  Smoke Herb Everyday         0.666667    10
#  414  Smoke Herb Everyday         0.583333    11
#  444  Smoke Herb Everyday         0.750000    12,
#          team_name  win_probability  week
#  18   The Mahomies         0.666667     0
#  57   The Mahomies         0.666667     1
#  84   The Mahomies         0.166667     2
#  114  The Mahomies         0.666667     3
#  159  The Mahomies         1.000000     4
#  198  The Mahomies         0.583333     5
#  219  The Mahomies         0.583333     6
#  276  The Mahomies         0.333333     7
#  321  The Mahomies         1.000000     8
#  357  The Mahomies         0.916667     9
#  384  The Mahomies         0.250000    10
#  417  The Mahomies         0.333333    11
#  456  The Mahomies         0.333333    12,
#                team_name  win_probability  week
#  33   The Salty  Spitoon         0.583333     0
#  69   The Salty  Spitoon         0.833333     1
#  72   The Salty  Spitoon         0.833333     2
#  135  The Salty  Spitoon         0.916667     3
#  162  The Salty  Spitoon         0.666667     4
#  195  The Salty  Spitoon         0.750000     5
#  225  The Salty  Spitoon         0.166667     6
#  264  The Salty  Spitoon         0.666667     7
#  303  The Salty  Spitoon         0.750000     8
#  342  The Salty  Spitoon         0.166667     9
#  387  The Salty  Spitoon         0.916667    10
#  426  The Salty  Spitoon         0.750000    11
#  450  The Salty  Spitoon         0.916667    12,
#                team_name  win_probability  week
#  12   Tua Legit Tua Quit         0.833333     0
#  42   Tua Legit Tua Quit         0.750000     1
#  87   Tua Legit Tua Quit         0.416667     2
#  126  Tua Legit Tua Quit         0.166667     3
#  171  Tua Legit Tua Quit         0.583333     4
#  180  Tua Legit Tua Quit         0.250000     5
#  249  Tua Legit Tua Quit         0.666667     6
#  285  Tua Legit Tua Quit         0.166667     7
#  312  Tua Legit Tua Quit         0.166667     8
#  345  Tua Legit Tua Quit         0.666667     9
#  372  Tua Legit Tua Quit         0.416667    10
#  411  Tua Legit Tua Quit         0.250000    11
#  438  Tua Legit Tua Quit         0.250000    12,
#                 team_name  win_probability  week
#  24   ¯\_(ツ)_/¯ ¯\_(ツ)_/¯         0.500000     0
#  39   ¯\_(ツ)_/¯ ¯\_(ツ)_/¯         0.333333     1
#  90   ¯\_(ツ)_/¯ ¯\_(ツ)_/¯         0.500000     2
#  123  ¯\_(ツ)_/¯ ¯\_(ツ)_/¯         0.750000     3
#  153  ¯\_(ツ)_/¯ ¯\_(ツ)_/¯         0.333333     4
#  192  ¯\_(ツ)_/¯ ¯\_(ツ)_/¯         0.166667     5
#  237  ¯\_(ツ)_/¯ ¯\_(ツ)_/¯         0.333333     6
#  270  ¯\_(ツ)_/¯ ¯\_(ツ)_/¯         0.500000     7
#  315  ¯\_(ツ)_/¯ ¯\_(ツ)_/¯         0.583333     8
#  354  ¯\_(ツ)_/¯ ¯\_(ツ)_/¯         0.333333     9
#  390  ¯\_(ツ)_/¯ ¯\_(ツ)_/¯         0.833333    10
#  423  ¯\_(ツ)_/¯ ¯\_(ツ)_/¯         0.833333    11
#  465  ¯\_(ツ)_/¯ ¯\_(ツ)_/¯         0.583333    12]

# %%
def simulate_wins_per_team(split_probs):
    '''Simulate 10000 seasons for the team, win_prob, week dataframe'''
    my_team_probs = split_probs.win_probability.to_list()
    simulated_season_wins = []
    for i in range(0,10000):
        simulated_season_wins.append(sum(simulate_season(my_team_probs)))
    wins_count = pd.Series(simulated_season_wins).value_counts().sort_index()
    probs = wins_count / wins_count.sum()
    #cusum_wins = probs.sort_index(ascending=False).cumsum().rename('probability')
    return probs

# %%
all_team_sims = []
for team in team_split:
    all_team_sims.append(simulate_wins_per_team(team))
full_season_all_probs = pd.concat(all_team_sims, axis=1).fillna(0)
full_season_all_probs.columns = team_names
full_season_all_probs.sort_index(ascending=False).cumsum().sort_index(ascending=True)
# Out:
#     49ers 14-6  American Russell  Clapped Cheeks  Double D Kupps  \
# 0       1.0000            1.0000          1.0000          1.0000
# 1       0.9974            1.0000          0.9998          1.0000
# 2       0.9688            1.0000          0.9964          1.0000
# 3       0.8635            0.9979          0.9700          1.0000
# 4       0.6459            0.9847          0.8735          1.0000
# 5       0.3746            0.9249          0.6721          0.9993
# 6       0.1640            0.7761          0.4040          0.9841
# 7       0.0532            0.5326          0.1789          0.9015
# 8       0.0133            0.2694          0.0557          0.6872
# 9       0.0019            0.0898          0.0115          0.4014
# 10      0.0003            0.0193          0.0012          0.1560
# 11      0.0001            0.0019          0.0000          0.0397
# 12      0.0000            0.0000          0.0000          0.0053
# 13      0.0000            0.0000          0.0000          0.0006
#
#     Edward  Jordyhands  Finding Deebo  It Ertz  When I Pee  \
# 0               1.0000         1.0000               1.0000
# 1               1.0000         1.0000               1.0000
# 2               1.0000         1.0000               1.0000
# 3               1.0000         0.9992               1.0000
# 4               1.0000         0.9909               0.9934
# 5               1.0000         0.9535               0.9446
# 6               0.9996         0.8315               0.7918
# 7               0.9945         0.6065               0.5423
# 8               0.9680         0.3464               0.2773
# 9               0.8868         0.1413               0.1009
# 10              0.7001         0.0392               0.0247
# 11              0.4204         0.0084               0.0034
# 12              0.1650         0.0004               0.0002
# 13              0.0291         0.0000               0.0000
#
#     Smoke Herb Everyday  The Mahomies  The Salty  Spitoon  Tua Legit Tua Quit  \
# 0                1.0000        1.0000              1.0000              1.0000
# 1                1.0000        1.0000              1.0000              0.9998
# 2                1.0000        1.0000              1.0000              0.9977
# 3                1.0000        1.0000              1.0000              0.9769
# 4                0.9999        0.9975              0.9997              0.9106
# 5                0.9945        0.9802              0.9987              0.7544
# 6                0.9682        0.9135              0.9886              0.5178
# 7                0.8820        0.7485              0.9520              0.2775
# 8                0.6888        0.5036              0.8394              0.1068
# 9                0.4159        0.2532              0.6262              0.0301
# 10               0.1746        0.0907              0.3595              0.0058
# 11               0.0469        0.0201              0.1272              0.0012
# 12               0.0058        0.0022              0.0231              0.0002
# 13               0.0003        0.0002              0.0019              0.0000
#
#     ¯\_(ツ)_/¯ ¯\_(ツ)_/¯
# 0                1.0000
# 1                1.0000
# 2                0.9996
# 3                0.9955
# 4                0.9729
# 5                0.8999
# 6                0.7468
# 7                0.5259
# 8                0.2922
# 9                0.1226
# 10               0.0355
# 11               0.0078
# 12               0.0005
# 13               0.0000

# %%
import altair as alt

# %%
alt.Chart(cusum_wins.reset_index()).mark_line().encode(x='index', y='probability', tooltip=[alt.Tooltip('index', title='Total H2H Wins'), 'probability']).interactive()
# Out:
# alt.Chart(...)
